# %% [markdown]
# # Libraries required

# %%
# # Libraries 
import os
from tensorflow.keras.models import Model
from pyabsa import ATEPCCheckpointManager, available_checkpoints
os.environ['PYTHONIOENCODING'] = 'UTF8'
import pandas as pd
import sys
import nltk
import ast
import re
import itertools
import numpy as np
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.corpus import wordnet
from nltk.corpus import sentiwordnet
from autocorrect import Speller
import  emoji
from textblob import TextBlob
import spacy
from ast import literal_eval
from numpy.core.defchararray import add
import findfile
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem.wordnet import WordNetLemmatizer 
import stanza
#nltk.download('stopwords')
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')
stop_words = set("english")
nlp = stanza.Pipeline('en')
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
tokenizer = PegasusTokenizer.from_pretrained("google/pegasus-xsum")
pd.get_option("display.max_columns")

import classy_classification
# Out:
# 2023-02-17 02:20:55.443357: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# No CUDA GPU found in your device
# Version 0.7.0 of metric_visualizer is outdated. Version 0.9.1 was released 11 hours ago.
# 2023-02-17 02:20:59.497553: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-02-17 02:20:59.497594: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-02-17 02:20:59.497623: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-172-31-92-167): /proc/driver/nvidia/version does not exist
# ...

# %% [markdown]
# # Paste Your review here

# %%
Sentence = """Even though I didn't frequent them all that often while they were still here, for quite a while, Buzz was my go-to spot for a tasty burger on this side of SF.  It wasn't amazing, nor the best value (Super Duper takes that distinction), but there was so much to like - friendly staff, plenty of parking, nary a wait, and, most importantly, the burgers were just solid.  So, needless to say, it was a bummer when I passed by and saw that they were gone.  Too bad I took such a long time to finally come here and check out their replacement.  If I hadn't, I would've discovered that even though Buzz may be gone, Native Burger really isn't all that different!

While their facade and aspects of their interior have changed (gone is the bench seating, replaced in favor of three picnic tables), not much about Native is all that different from its predecessor.  The menu, in particular, might look all too familiar; like Buzz's, it also not very extensive (though it does have a few more options) and some of the burgers even bear the same name, such as the Western and Sunrise.  However, their dozen or so burgers, as well as their handful of sides, sausages, salad, and loco moco, are rather appealing.  What's more, they have quite a few substitute options, if needed (non-Gluten bun, Lettuce Wrap, and non-beef proteins, like Beyond, Chicken, and Turkey).

-- ONION RINGS...$4.25
(yelp.com/biz_photos/nati…)
These aren't the best I've had, but after not having legit onion rings in ages, I thought these were terrific!  The rings were crispy, not overly battered, and were cut fairly thick.  It doesn't come with dipping sauce, but they happily gave me a side of ranch for free.

-- NATIVE BURGER - 7oz Harris Ranch Grass Fed Beef, 4oz Applewood Smoked "Fool's Gold" Bacon, Sunny Farms Cheddar, Lettuce, Tomato, and House BBQ Sauce on a Brioche Bun...$15.75
(yelp.com/biz_photos/nati…)
More solid than spectacular, but still quite tasty!  The patty was well cooked, I LOVED the bacon's salty sweetness, and everything complemented each other really well.  That being said, whether it be due to the patty, the bacon, or both, the burger, as a whole, felt a little greasy.

-- JR. CLASSIC BURGER & FRIES - 4oz Harris Ranch Grass Fed Beef, Sunny Farms Cheddar, Lettuce, Tomato, Red Onions, Pringle Cut Dill Pickles, and House Island Sauce on a Brioche Bun with Twice Fried Fries...$11.25
(yelp.com/biz_photos/nati…)
This was...pretty awesome.  Not only is the burger the perfect size, but it was done so well - juicy patty, a soft, toasted bun, and fresh veggies.  As for the fries, they were far better than the garlic version.  All together, this feels like a terrific value for what you get!

-- GARLIC FRIES...$4.50
(yelp.com/biz_photos/nati…)
Meh.  These fries were also very crispy, and the portion was decent, but the taste was underwhelming.  Not only was it not very garlicky/lacking in garlic, but there wasn't much else to it either - no herbs, no cheese, not much seasoning.  It has potential, but disappointed as is.

-- LOCO MOCO - Two Range Free Eggs, 7oz Grass Fed Harris Ranch Beef, and Housemade Gravy Over Jasmine Rice...$12.25
(yelp.com/biz_photos/nati…)
Are they to blame for this one or am I for ordering it?  Not surprisingly, the patties were the best part, as they were both juicy and flavorful.  Everything else, other then the eggs, was a bust - the onions were mealy, the rice was hard, and the gravy was gloppy and broken.

While most of what I've had has been more good than bad, the service here has been excellent all around.  Every time I've stopped in, the same two guys have been working the register and grill and they've always been super friendly.  They've happily given us ranch for the onion rings and garlic fries (much needed for the latter) and they're quick to greet people/say goodbye as folks come and go.  Tasty burgers, friendly service, and a wealth of parking nearby?  Super Duper's newest outpost is a short walk away, but it's great  to know that Native is just as good as my former go-to spot!"""

# %% [markdown]
# # Overall Sentiment

# %%
#VADER Sentiment Analysis

def sentiment_vader(sentence):

    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()

    # polarity_scores method of SentimentIntensityAnalyzer
    # object gives a sentiment dictionary.
    # which contains pos, neg, neu, and compound scores.
    sentiment_dict = sid_obj.polarity_scores(sentence)
    negative = sentiment_dict['neg']
    neutral = sentiment_dict['neu']
    positive = sentiment_dict['pos']
    compound = sentiment_dict['compound']

    # print("Overall sentiment dictionary is : ", sentiment_dict)
    # print("sentence was rated as ", sentiment_dict['neg']*100, "% Negative")
    # print("sentence was rated as ", sentiment_dict['neu']*100, "% Neutral")
    # print("sentence was rated as ", sentiment_dict['pos']*100, "% Positive")
    #
    # print("Sentence Overall Rated As", end = " ")
    #
    # decide sentiment as positive, negative and neutral
    if sentiment_dict['compound'] >= 0.05 :
        overall_sentiment = "Positive"
        # print("Positive")

    elif sentiment_dict['compound'] <= - 0.05 :
        overall_sentiment = "Negative"
        # print("Negative")

    else :
        overall_sentiment = "Neutral"
        # print("Neutral")
    #
    return overall_sentiment

# %%
print("Overall Sentiment of the Review : {} ".format(sentiment_vader(Sentence)))
# Out:
# Overall Sentiment of the Review : Positive

# %% [markdown]
# # Review Summarization

# %%
model = PegasusForConditionalGeneration.from_pretrained("google/pegasus-xsum")
def summarizer(Sentence):
    tokens = tokenizer(Sentence, truncation=True, padding="longest", return_tensors="pt")
    summary = model.generate(**tokens)
    return tokenizer.decode(summary[0])

# %%
print("Summarizing the Review : {} ".format(summarizer(Sentence)))
# Out:
# Summarizing the Review : When Buzz Burger closed its doors a few months ago, I was sad to see it go.

# %% [markdown]
# # Aspect based Sentiment Analysis Quadraplet Extraction (Unsupervised)

# %%
# Preprocessing -----------------------------------------------------------------------


#Spell Check coorect word 
def correct_word (word):
    spell = Speller(lang='en')
    return spell(word)
def undo_contractions(phrase):
    # specific
    phrase = re.sub(r"won[\'’]t", "will not", phrase)
    phrase = re.sub(r"can[\'’]t", "can not", phrase)
    # general
    phrase = re.sub(r"n[\'’]t", " not", phrase)
    phrase = re.sub(r"[\'’]re", " are", phrase)
    phrase = re.sub(r"[\'’]s", " is", phrase)
    phrase = re.sub(r"[\'’]d", " would", phrase)
    phrase = re.sub(r"[\'’]ll", " will", phrase)
    phrase = re.sub(r"[\'’]t", " not", phrase)
    phrase = re.sub(r"[\'’]ve", " have", phrase)
    phrase = re.sub(r"[\'’]m", " am", phrase)
    return phrase



def aspect_sentiment_analysis(txt, stop_words, nlp):
    xt = txt.lower() # LowerCasing the given Text
    sentList = nltk.sent_tokenize(txt) # Splitting the text into sentences

    fcluster = []
    totalfeatureList = []
    finalcluster = []
    dic = {}

    for line in sentList:
        newtaggedList = []
        txt_list = nltk.word_tokenize(line) # Splitting up into words
        taggedList = nltk.pos_tag(txt_list) # Doing Part-of-Speech Tagging to each word

        newwordList = []
        flag = 0
        for i in range(0,len(taggedList)-1):
            if(taggedList[i][1]=="NN" and taggedList[i+1][1]=="NN"): # If two consecutive words are Nouns then they are joined together
                newwordList.append(taggedList[i][0]+taggedList[i+1][0])
                flag=1
            else:
                if(flag==1):
                    flag=0
                    continue
                newwordList.append(taggedList[i][0])
                if(i==len(taggedList)-2):
                    newwordList.append(taggedList[i+1][0])

        finaltxt = ' '.join(word for word in newwordList) 
        new_txt_list = nltk.word_tokenize(finaltxt)
        wordsList = [w for w in new_txt_list if not w in stop_words]
        taggedList = nltk.pos_tag(wordsList)

        doc = nlp(finaltxt) # Object of Stanford NLP Pipeleine
        
        # Getting the dependency relations betwwen the words
        dep_node = []
        for dep_edge in doc.sentences[0].dependencies:
            dep_node.append([dep_edge[2].text, dep_edge[0].id, dep_edge[1]])

        # Coverting it into appropriate format
        for i in range(0, len(dep_node)):
            if (int(dep_node[i][1]) != 0):
                dep_node[i][1] = newwordList[(int(dep_node[i][1]) - 1)]

        featureList = []
        categories = []
        for i in taggedList:
            if(i[1]=='JJ' or i[1]=='NN' or i[1]=='JJR' or i[1]=='NNS' or i[1]=='RB'):
                featureList.append(list(i)) # For features for each sentence
                totalfeatureList.append(list(i)) # Stores the features of all the sentences in the text
                categories.append(i[0])

        for i in featureList:
            filist = []
            for j in dep_node:
                if((j[0]==i[0] or j[1]==i[0]) and (j[2] in ["nsubj", "acl:relcl", "obj", "dobj", "agent", "advmod", "amod", "neg", "prep_of", "acomp", "xcomp", "compound"])):
                    if(j[0]==i[0]):
                        filist.append(j[1])
                    else:
                        filist.append(j[0])
            fcluster.append([i[0], filist])
            
    for i in totalfeatureList:
        dic[i[0]] = i[1]
    
    for i in fcluster:
        if(dic[i[0]]=="NN"):
            finalcluster.append(i)
        
    return(finalcluster)

# %%
def absa_triple(Sentence, data):
    sent = Sentence.replace(r'([a-z]+)([A-Z])', r'\1 \2').lower().replace('\n', '.').replace(r'\s*\.+\s*', '. ') .replace(r'([\{\(\[\}\)\]])', r' \1 ') .replace(r'([:])', r' \1 ').replace(r'(\d+\.?\d*)', r' \1 ')
    sent = undo_contractions(sent)
    clean_text = correct_word(sent)
    nlp = spacy.load("en_core_web_sm")
    #Convert in to list of sentences....................................
    sentences = [i.text.strip() for i in nlp(clean_text).sents]


    # Applying PyABSA Model

    aspect_extractor = ATEPCCheckpointManager.get_aspect_extractor(checkpoint='multilingual',
                                                               auto_device=True  # False means load model on CPU
                                                               )


    def inference(text):
        result = aspect_extractor.extract_aspect(inference_source=[text],
                                             pred_sentiment=True)

        result = pd.DataFrame({
        'aspect': result[0]['aspect'],
        'sentiment': result[0]['sentiment']
        })

        return result


    result1 = aspect_extractor.extract_aspect(inference_source=sentences,
                                          save_result=False,
       
                                          print_result=True,
                                          pred_sentiment=True)



    result = pd.DataFrame(result1)
    result = result[['sentence', 'aspect', 'sentiment']]

    # Converting the resultant Dataframe in to a certain format.. 


    def convert(df):
        df['sentence'] = df['sentence'].astype('str') 
        df['aspect'] = df['aspect'].apply(lambda x: np.array(x))
        df['sentiment'] = df['sentiment'].apply(lambda x: np.array(x))
        df =df.dropna()
 
        df['aspect'] = df['aspect'].values.tolist()
        df['sentiment'] = df['sentiment'].values.tolist()

        df['tup'] = df.apply(lambda x: list(zip(x.aspect,x.sentiment)), axis=1)
        df['tup'] = df['tup'].astype('str').apply(literal_eval)
        df2 =df.explode('tup')
        df2 = df2.drop(['aspect', 'sentiment'], 1)
        df2['aspect'], df2['aspect_sentiment'] = df2.tup.str
        df2 = df2.drop_duplicates()
        df2 =df2.drop('tup', axis=1)

        return df2


    #Exploding Aspects
    df2 = convert(result)
    filtered_df = df2[df2['aspect'].notnull()].reset_index(drop = True)
    filtered_df['sent_index'] = filtered_df.groupby('sentence', sort=False).ngroup() + 1

    # List of sentences and aspects
    n_asp = filtered_df['sentence'].tolist()
    asp = filtered_df['aspect'].tolist()

    ###Aspect Category Detection ..................................
    nlp = spacy.blank("en")
    nlp.add_pipe(
        "text_categorizer",
        config={
            "data": data,
            "model": "typeform/distilbert-base-uncased-mnli",
            "cat_type": "zero",
        }
    )


    lst1 = []
    for i in n_asp:
        dct = nlp(i)._.cats
        keyMax =max(zip(dct.values(), dct.keys()))[1]

        lst1.append(keyMax)


    filtered_df['aspect_category'] = lst1

    return(filtered_df)

# %%
# List of Categories for Games
#data = ["Gameplay", "Performance Issues", "Other", "Narrative", "Graphics", "Level design", "Multiplayer", "Value for Money", "Replay Value"]
# List of Categories for resturant
data = ["Food","Service", "Ambiance", "Other"] 


df = absa_triple(Sentence,data)
# Out:
# FindFile Warning --> multiple targets ['absa/updated_code/checkpoints/ATEPC_MULTILINGUAL_CHECKPOINT/fast_lcf_atepc.config', 'main/checkpoints/ATEPC_MULTILINGUAL_CHECKPOINT/fast_lcf_atepc.config', 'checkpoints/ATEPC_MULTILINGUAL_CHECKPOINT/fast_lcf_atepc.config'] found, only return the shortest path: <checkpoints/ATEPC_MULTILINGUAL_CHECKPOINT/fast_lcf_atepc.config>
# [2023-02-17 02:21:35] (2.0.23) Load aspect extractor from checkpoints/ATEPC_MULTILINGUAL_CHECKPOINT
# [2023-02-17 02:21:35] (2.0.23) config: checkpoints/ATEPC_MULTILINGUAL_CHECKPOINT/fast_lcf_atepc.config
# [2023-02-17 02:21:35] (2.0.23) state_dict: checkpoints/ATEPC_MULTILINGUAL_CHECKPOINT/fast_lcf_atepc.state_dict
# [2023-02-17 02:21:35] (2.0.23) model: None
# [2023-02-17 02:21:35] (2.0.23) tokenizer: checkpoints/ATEPC_MULTILINGUAL_CHECKPOINT/fast_lcf_atepc.tokenizer
# [2023-02-17 02:21:35] (2.0.23) Set Model Device: cpu
# [2023-02-17 02:21:35] (2.0.23) Device Name: Unknown
# ...

# %%
df
# Out:
#                                              sentence        aspect  \
# 0   even though i did not frequent them all that o...        burger
# 1   it was not amazing , nor the best value ( supe...         value
# 2   it was not amazing , nor the best value ( supe...         staff
# 3   it was not amazing , nor the best value ( supe...       parking
# 4   it was not amazing , nor the best value ( supe...          wait
# 5   it was not amazing , nor the best value ( supe...       burgers
# 6   the menu , in particular , might look all too ...          menu
# 7   the menu , in particular , might look all too ...       burgers
# 8   however , their dozen or so burgers , as well ...       burgers
# 9   however , their dozen or so burgers , as well ...         sides
# 10  however , their dozen or so burgers , as well ...      sausages
# 11  however , their dozen or so burgers , as well ...         salad
# 12    $ 4 . 25 . ( help . com / biz _ photos / nat...   legit onion
# ...

# %% [markdown]
# # Opinion Term Extraction - OTE

# %%
asp = df['aspect'].tolist()
n_asp = df['sentence'].tolist()
import re
n_sp = []
for query in n_asp:
    query1 = re.sub(r'[^ \w+]', '', query).replace("_", " ").replace("+"," ").strip()
    n_sp.append(query1)

# %%
l_sup = []
for i in n_sp:
    try:
        l_sup.append(aspect_sentiment_analysis(i, stop_words, nlp))
        print(aspect_sentiment_analysis(i, stop_words, nlp))
    except:
        l_sup.append([])
# Out:
# [['whilebuzz', []], ['go', []], ['burger', ['tasty']], ['side', []], ['sf', []]]
# [['valuesuper', ['supersuper']], ['supersuper', ['best', 'valuesuper', 'takes']], ['distinction', ['takes']], ['staffplenty', ['friendly', 'like']], ['wait', []]]
# [['valuesuper', ['supersuper']], ['supersuper', ['best', 'valuesuper', 'takes']], ['distinction', ['takes']], ['staffplenty', ['friendly', 'like']], ['wait', []]]
# [['valuesuper', ['supersuper']], ['supersuper', ['best', 'valuesuper', 'takes']], ['distinction', ['takes']], ['staffplenty', ['friendly', 'like']], ['wait', []]]
# [['valuesuper', ['supersuper']], ['supersuper', ['best', 'valuesuper', 'takes']], ['distinction', ['takes']], ['staffplenty', ['friendly', 'like']], ['wait', []]]
# [['valuesuper', ['supersuper']], ['supersuper', ['best', 'valuesuper', 'takes']], ['distinction', ['takes']], ['staffplenty', ['friendly', 'like']], ['wait', []]]
# [['menu', ['look']], ['buzz', []], ['name', ['same', 'bear']], ['sunrise', []]]
# ...

# %%
dct ={}
for i in range(0,len(l_sup)):
    lst1 = l_sup[i]
    for j in range(0,len(lst1)):
        if asp[i].replace(" ", "") == lst1[j][0] or asp[i] in lst1[j][0]:
            dct[i] = lst1[j][1]

# %%
for i in range(len(l_sup)):
    if i not in dct:
        dct[i] = []

# %%
sd = {k : dct[k] for k in sorted(dct)}
opin = list(sd.values())
df['opinions'] =  opin

# %%
pd.set_option('display.max_colwidth', None)

# %%
df
# Out:
#                                                                                                                                                                                                                                                   sentence  \
# 0                                                                                     even though i did not frequent them all that often while they were still here , for quite a while , buzz was my go - to spot for a tasty burger on this side of sf .
# 1                               it was not amazing , nor the best value ( super super takes that distinction ) , but there was so much to like - friendly staff , plenty of parking , navy a wait , and , most importantly , the burgers were just solid .
# ...
